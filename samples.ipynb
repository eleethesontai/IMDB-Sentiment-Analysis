# %%
# imports 

import tarfile
import os
import pandas as pd
import requests

# %%
# download the training data

url = 'https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz'

directory = 'temp'
file_name = 'aclImdb_v1.tar.gz'
file_path = os.path.join(directory, file_name)

if not os.path.exists(directory):
    os.makedirs(directory)

response = requests.get(url)

if response.status_code == 200:
    with open(file_path, 'wb') as file:
        file.write(response.content)
    print(f"Downloaded {file_path} successfully!")
else:
    print("Failed to download the file.")

# %%
# decompress

with tarfile.open(file_path, 'r:gz') as tar:
    tar.extractall(path='temp/')

# %%
# transform the data files to useable shape

folders = [
    {"folder": 'temp/aclImdb/train/neg', "label": 0},
    {"folder": 'temp/aclImdb/train/pos', "label": 1},
    {"folder": 'temp/aclImdb/test/neg', "label": 0},
    {"folder": 'temp/aclImdb/test/pos', "label": 1},
]
results = []

for d in folders:
    for f in os.listdir(d['folder']):
        with open(os.path.join(d['folder'],f), 'r', encoding='UTF-8') as file:
            results.append([file.read(),d['label']])

# %%
# write to csv

data = pd.DataFrame(results, columns=['Review','Sentiment'])
data.to_csv('samples.csv', index=False)
